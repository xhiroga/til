# %%
# !git clone https://github.com/mrok273/Qiita
# Out:
# fatal: destination path 'Qiita' already exists and is not an empty directory.

# %%
import matplotlib.pyplot as plt

from PIL import Image
from torchvision import transforms

# %%
image = Image.open("Qiita/ポケモン/poke_vs_digi/data/poke_old/006Charizard_RG.png")
plt.imshow(image)
plt.axis('off')
plt.show()
