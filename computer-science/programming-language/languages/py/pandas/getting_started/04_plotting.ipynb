# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# Out:
# Unable to revert mtime: /Library/Fonts
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
air_quality = pd.read_csv('data/air_quality_no2.csv', index_col=0, parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot() # `plot`自体をメソッドとして呼び出した場合は、折れ線グラフ(One line plot)として描画
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
type(air_quality["station_paris"]) # 時系列データの場合、値とは別に時系列情報を保持したSeriesオブジェクトが生成される
# Out:
# pandas.core.series.Series

# %%
air_quality["station_paris"].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.box()
# Out:
# <AxesSubplot:>

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

# %%
fig, axs =  plt.subplots(figsize=(12,4))

# %%
air_quality.plot.area(ax=axs)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
axs.set_ylabel("NO$_2$ concentration")
# Out:
# Text(3.200000000000017, 0.5, 'NO$_2$ concentration')

# %%
fig.savefig("data/no2_concentrations.png")
