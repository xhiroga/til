# %%
import gymnasium as gym
from stable_baselines3 import PPO

env = gym.make('CartPole-v1', render_mode='human')
model = PPO('MlpPolicy', env, verbose=1, device='cuda')
model.learn(total_timesteps=50000)

state, _ = env.reset()

while True:
    env.render()
    action, _states = model.predict(state, deterministic=True)
    state, reward, done, _, _ = env.step(action)

    if done:
        break

env.close()
# TODO: This program does not stop properly.
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 21.5     |
# | time/              |          |
# |    fps             | 46       |
# |    iterations      | 1        |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.4        |
# |    ep_rew_mean          | 26.4        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 2           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008093918 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.000887   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.74        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 48          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34          |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 3           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012275051 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.0899      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 34          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.1         |
# |    ep_rew_mean          | 47.1         |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 4            |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0089480365 |
# |    clip_fraction        | 0.0818       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0196      |
# |    value_loss           | 54           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.1         |
# |    ep_rew_mean          | 61.1         |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 5            |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0068334285 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.618       |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0137      |
# |    value_loss           | 65.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.3        |
# |    ep_rew_mean          | 79.3        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 6           |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006418949 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 64.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 93.6       |
# |    ep_rew_mean          | 93.6       |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 7          |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00477059 |
# |    clip_fraction        | 0.0356     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.589     |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.5       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00789   |
# |    value_loss           | 60.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 8            |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0051940344 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.009       |
# |    value_loss           | 59.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 9           |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007922666 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9           |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 10           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0086869225 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.17         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00891     |
# |    value_loss           | 31.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 11          |
# |    time_elapsed         | 478         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007203228 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 28          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 180          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 12           |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0054085283 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.753        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.25         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0063      |
# |    value_loss           | 35.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 13           |
# |    time_elapsed         | 563          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0031167772 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.31         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -9.92e-05    |
# |    value_loss           | 23           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 14          |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005925537 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.000307   |
# |    value_loss           | 12.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 230          |
# |    ep_rew_mean          | 230          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 15           |
# |    time_elapsed         | 649          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0027452921 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.378        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 4.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 16          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007726231 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 1.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 268          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 17           |
# |    time_elapsed         | 734          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0056467527 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0945       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000851    |
# |    value_loss           | 0.716        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 286         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 18          |
# |    time_elapsed         | 777         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009768289 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.651       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 303         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 19          |
# |    time_elapsed         | 820         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006063743 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0616      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 0.286       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | 318          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 20           |
# |    time_elapsed         | 862          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0043639345 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | -0.0187      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0176       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000351    |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 333         |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 21          |
# |    time_elapsed         | 905         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004189468 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00624    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 351          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 22           |
# |    time_elapsed         | 948          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049970886 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000265    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.0705       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 365          |
# |    ep_rew_mean          | 365          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 23           |
# |    time_elapsed         | 991          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0021273494 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0212       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000962    |
# |    value_loss           | 0.046        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 378          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 24           |
# |    time_elapsed         | 1033         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0014519629 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.0555       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00822      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 0.0294       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 391          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 25           |
# |    time_elapsed         | 1076         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0063505587 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00317      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 0.019        |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 state, _ = env.reset()
#      10 while True:
# ---> 11     env.render()
#      12     action, _states = model.predict(state, deterministic=True)
#      13     state, reward, done, _, _ = env.step(action)
#
# File c:\Users\hiroga\miniconda3\envs\til_machine_learning_py312\Lib\site-packages\gymnasium\core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File c:\Users\hiroga\miniconda3\envs\til_machine_learning_py312\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File c:\Users\hiroga\miniconda3\envs\til_machine_learning_py312\Lib\site-packages\gymnasium\wrappers\env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File c:\Users\hiroga\miniconda3\envs\til_machine_learning_py312\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
